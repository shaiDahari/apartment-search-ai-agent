# %%
import sys

print(sys.executable)
# Out:
# /home/shaid/projects/rental-agent/.venv/bin/python

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import sqlalchemy
import pymysql
import apscheduler

print("Notebook environment OK")
# Out:
# Notebook environment OK
